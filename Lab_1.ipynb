# %% [markdown]
# <a href="https://colab.research.google.com/github/NandhiniVugge/AIML/blob/main/Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Mathematical Operations using Numpy

# %%
import numpy as np
list1 =[3,2,1]
list2 = [3,2,1]
array1 = np.array(list1)
array2 = np.array(list2)
print(f'Log2 value of array1:,{np.sin(array1)}')
# Out:
# Log2 value of array1:,[0.14112001 0.90929743 0.84147098]

# %%
print(f'Exponential value of array1:,{np.exp(array1)}')
# Out:
# Exponential value of array1:,[20.08553692  7.3890561   2.71828183]

# %%
data visualization with matplotlib
# Out:
#   File "<ipython-input-14-2a4268a35f4b>", line 1
#     data visualization with matplotlib
#          ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
people = ['nan','var','sow','sush','ani']
age = [21,23,33,12,25]
weight=[55,65,44,23,60]
height=[160,123,122,145,134]
plt.scatter(height,age,weight)
plt.figure(figsize=(5,4))
plt.title("People's weight in Kgs",fontsize=16,fontstyle='italic')
#main plot function Bar
plt.bar(x=people,height=weight,width=0.6,color='orange',edgecolor='k',alpha=0.6)
plt.xlabel("People",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("weight (in kgs)",fontsize=15)
plt.show()

# %%
import numpy as np
people = ['nan','var','sow','sush','ani']
age = [21,23,33,12,25]
weight=[55,65,44,23,60]
height=[160,123,122,145,134]
plt.figure(figsize=(5,4))
#Main plot function 'hist'
plt.hist(weight,color='red',edgecolor='k',alpha=0.75,bin=4)
plt.title("Histogram of Patient weight",fontsize=15)
plt.xlabel("weight in kgs",fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-a249e69559fd> in <cell line: 8>()
#       6 plt.figure(figsize=(5,4))
#       7 #Main plot function 'hist'
# ----> 8 plt.hist(weight,color='red',edgecolor='k',alpha=0.75,bin=4)
#       9 plt.title("Histogram of Patient weight",fontsize=15)
#      10 plt.xlabel("weight in kgs",fontsize=15)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2643         orientation='vertical', rwidth=None, log=False, color=None,
#    2644         label=None, stacked=False, *, data=None, **kwargs):
# -> 2645     return gca().hist(
#    2646         x, bins=bins, range=range, density=density, weights=weights,
# ...
